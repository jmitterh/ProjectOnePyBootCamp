# %%
#imports 
import json
import os
import requests
import pandas as pd
import matplotlib as plt
import pprint as pprint
from pandas.io.json import json_normalize
import gmaps
import gmaps.datasets

# %%
# data file to be saved
rawData = "../data/rawData/jp_normalized_dataframe.csv"


# renamed data file to be saved
orgRawData = "../data/rawData/jp_organized_dataframe.csv"

# cleaned data file to be saved
cleanData = "../data/cleanData/jp_clean_data.csv"

# path csv file location
pathRawData = "../data/rawData/"
pathCleanData ="../datacleanData/"

# %%
# Remember to update the config file with your API key
from config import api_key
from config import api_id
from config import gkey

# %%
url = "https://api.adzuna.com/v1/api/jobs/us/search/"
#have to create iteration to get all pages of data
page = "1"
api_details ="?" + "app_id=" + api_id + "&app_key=" + api_key
# Build query URL
query_url = url + page + api_details
query_url
# Out:
# 'https://api.adzuna.com/v1/api/jobs/us/search/1?app_id=a9ccf687&app_key=40f9330010ceb8d80cf656346e80a002'

# %%
data_response = requests.get(query_url)
data_json = data_response.json()
type(data_json)
# Out:
# dict

# %%
#Getting data using json_normalize
#LINK: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.json.json_normalize.html

pages_test = [str(x) for x in range(1,101)]

counter = 0
# Build query URL
data_pages_df = pd.DataFrame()

for page_num in pages_test:
    response = requests.get(url + page_num + api_details).json()
    
    #create a df to store the normalized page that has the job postings
    normalized_page = json_normalize(response['results'])
    
    #add normalized data into a df
    data_page_df = pd.DataFrame(normalized_page)
    
    #add the url column to df incase an error occurs you know what page you were on
    data_page_df['query_url'] = 'page number ' + page_num
    
    #append to a new df so each page can be saved
    #Sorting because non-concatenation axis is not aligned
    data_pages_df = data_pages_df.append(data_page_df, sort=True)
    
    counter += 1
    print(f"Page {page_num} iteration complete")
    
print(f'total rows iterated | {counter * 10}')
# Out:
# Page 1 iteration complete
# Page 2 iteration complete
# Page 3 iteration complete
# Page 4 iteration complete
# Page 5 iteration complete
# Page 6 iteration complete
# Page 7 iteration complete
# Page 8 iteration complete
# Page 9 iteration complete
# Page 10 iteration complete
# Page 11 iteration complete
# Page 12 iteration complete
# Page 13 iteration complete
# Page 14 iteration complete
# Page 15 iteration complete
# Page 16 iteration complete
# Page 17 iteration complete
# Page 18 iteration complete
# Page 19 iteration complete
# Page 20 iteration complete
# Page 21 iteration complete
# Page 22 iteration complete
# Page 23 iteration complete
# Page 24 iteration complete
# Page 25 iteration complete
# Page 26 iteration complete
# Page 27 iteration complete
# Page 28 iteration complete
# Page 29 iteration complete
# Page 30 iteration complete
# Page 31 iteration complete
# Page 32 iteration complete
# Page 33 iteration complete
# Page 34 iteration complete
# Page 35 iteration complete
# Page 36 iteration complete
# Page 37 iteration complete
# Page 38 iteration complete
# Page 39 iteration complete
# Page 40 iteration complete
# Page 41 iteration complete
# Page 42 iteration complete
# Page 43 iteration complete
# Page 44 iteration complete
# Page 45 iteration complete
# Page 46 iteration complete
# Page 47 iteration complete
# Page 48 iteration complete
# Page 49 iteration complete
# Page 50 iteration complete
# Page 51 iteration complete
# Page 52 iteration complete
# Page 53 iteration complete
# Page 54 iteration complete
# Page 55 iteration complete
# Page 56 iteration complete
# Page 57 iteration complete
# Page 58 iteration complete
# Page 59 iteration complete
# Page 60 iteration complete
# Page 61 iteration complete
# Page 62 iteration complete
# Page 63 iteration complete
# Page 64 iteration complete
# Page 65 iteration complete
# Page 66 iteration complete
# Page 67 iteration complete
# Page 68 iteration complete
# Page 69 iteration complete
# Page 70 iteration complete
# Page 71 iteration complete
# Page 72 iteration complete
# Page 73 iteration complete
# Page 74 iteration complete
# Page 75 iteration complete
# Page 76 iteration complete
# Page 77 iteration complete
# Page 78 iteration complete
# Page 79 iteration complete
# Page 80 iteration complete
# Page 81 iteration complete
# Page 82 iteration complete
# Page 83 iteration complete
# Page 84 iteration complete
# Page 85 iteration complete
# Page 86 iteration complete
# Page 87 iteration complete
# Page 88 iteration complete
# Page 89 iteration complete
# Page 90 iteration complete
# Page 91 iteration complete
# Page 92 iteration complete
# Page 93 iteration complete
# Page 94 iteration complete
# Page 95 iteration complete
# Page 96 iteration complete
# Page 97 iteration complete
# Page 98 iteration complete
# Page 99 iteration complete
# Page 100 iteration complete
# total rows iterated | 1000

# %%
#save raw data to dataRaw folder
data_pages_df.to_csv(rawData)

# %%
#calling the csv raw data
csv_file = pd.read_csv(rawData)
csv_file.head()
# Out:
#    Unnamed: 0                   __CLASS__  \
# 0           0  Adzuna::API::Response::Job
# 1           1  Adzuna::API::Response::Job
# 2           2  Adzuna::API::Response::Job
# 3           3  Adzuna::API::Response::Job
# 4           4  Adzuna::API::Response::Job
#
#                                                adref  \
# 0  eyJhbGciOiJIUzI1NiJ9.eyJpIjoxMzI4MjQxMzM3LCJzI...
# 1  eyJhbGciOiJIUzI1NiJ9.eyJpIjoxMzI4MjQyMDAxLCJzI...
# 2  eyJhbGciOiJIUzI1NiJ9.eyJzIjoidDFwUjRoWE1RdGFYT...
# 3  eyJhbGciOiJIUzI1NiJ9.eyJzIjoidDFwUjRoWE1RdGFYT...
# 4  eyJhbGciOiJIUzI1NiJ9.eyJpIjoxMzEyODA0ODEzLCJzI...
#
#                 category.__CLASS__             category.label  \
# 0  Adzuna::API::Response::Category  Healthcare & Nursing Jobs
# 1  Adzuna::API::Response::Category  Healthcare & Nursing Jobs
# 2  Adzuna::API::Response::Category  Healthcare & Nursing Jobs
# 3  Adzuna::API::Response::Category  Healthcare & Nursing Jobs
# 4  Adzuna::API::Response::Category  Healthcare & Nursing Jobs
#
#               category.tag               company.__CLASS__  \
# 0  healthcare-nursing-jobs  Adzuna::API::Response::Company
# 1  healthcare-nursing-jobs  Adzuna::API::Response::Company
# 2  healthcare-nursing-jobs  Adzuna::API::Response::Company
# 3  healthcare-nursing-jobs  Adzuna::API::Response::Company
# 4  healthcare-nursing-jobs  Adzuna::API::Response::Company
#
#   company.display_name contract_time contract_type  ...          id  \
# 0           CompHealth           NaN           NaN  ...  1328241337
# 1           CompHealth           NaN           NaN  ...  1328242001
# 2           CompHealth           NaN           NaN  ...  1312805447
# 3           CompHealth           NaN           NaN  ...  1316877274
# 4           CompHealth           NaN           NaN  ...  1312804813
#
#     latitude               location.__CLASS__  \
# 0  27.955269  Adzuna::API::Response::Location
# 1  39.844003  Adzuna::API::Response::Location
# 2  41.532259  Adzuna::API::Response::Location
# 3  40.819260  Adzuna::API::Response::Location
# 4  32.420674  Adzuna::API::Response::Location
#
#                                        location.area  \
# 0  ['US', 'Florida', 'Hillsborough County', 'Tampa']
# 1  ['US', 'New Jersey', 'Camden County', 'Somerda...
# 2         ['US', 'Indiana', 'Lake County', 'Hobart']
# 3                             ['US', 'Pennsylvania']
# 4    ['US', 'New Mexico', 'Eddy County', 'Carlsbad']
#
#         location.display_name   longitude      query_url  \
# 0  Tampa, Hillsborough County  -82.456320  page number 1
# 1    Somerdale, Camden County  -75.022669  page number 1
# 2         Hobart, Lake County  -87.255035  page number 1
# 3            Pennsylvania, US  -77.565308  page number 1
# 4       Carlsbad, Eddy County -104.228838  page number 1
#
#                                         redirect_url salary_is_predicted  \
# 0  https://www.adzuna.com/land/ad/1328241337?se=t...                   0
# 1  https://www.adzuna.com/land/ad/1328242001?se=t...                   0
# 2  https://www.adzuna.com/land/ad/1312805447?se=t...                   0
# 3  https://www.adzuna.com/land/ad/1316877274?se=t...                   0
# 4  https://www.adzuna.com/land/ad/1312804813?se=t...                   0
#
#                                                title
# 0  Physician: Florida Private Practice Looking fo...
# 1  Physician: Urgent Care Physician Position in S...
# 2  Physician: Obstetrics/Gynecology Opportunity i...
# 3  Physician: Facility in PA Is Looking for a Tem...
# 4  Physician: OB/GYN Needed in Carlsbad, New Mexi...
#
# [5 rows x 22 columns]

# %%
#making a copy
csv_file_copy = csv_file.copy()

#getting only the rows that we are using
csv_file_copy = csv_file_copy[["id","title","category.label","company.display_name", "location.display_name", "latitude","longitude" ]]
csv_file_copy.head()
# Out:
#            id                                              title  \
# 0  1328241337  Physician: Florida Private Practice Looking fo...
# 1  1328242001  Physician: Urgent Care Physician Position in S...
# 2  1312805447  Physician: Obstetrics/Gynecology Opportunity i...
# 3  1316877274  Physician: Facility in PA Is Looking for a Tem...
# 4  1312804813  Physician: OB/GYN Needed in Carlsbad, New Mexi...
#
#               category.label company.display_name       location.display_name  \
# 0  Healthcare & Nursing Jobs           CompHealth  Tampa, Hillsborough County
# 1  Healthcare & Nursing Jobs           CompHealth    Somerdale, Camden County
# 2  Healthcare & Nursing Jobs           CompHealth         Hobart, Lake County
# 3  Healthcare & Nursing Jobs           CompHealth            Pennsylvania, US
# 4  Healthcare & Nursing Jobs           CompHealth       Carlsbad, Eddy County
#
#     latitude   longitude
# 0  27.955269  -82.456320
# 1  39.844003  -75.022669
# 2  41.532259  -87.255035
# 3  40.819260  -77.565308
# 4  32.420674 -104.228838

# %%
#Renaming the column names

renamed_csv_file = csv_file_copy.rename(columns = {
    "id": "Job Posting ID",
    "title": "Job Title",
    "category.label":"Category",
    "company.display_name":"Company Name",
    "location.display_name":"Location",
    "latitude":"Lat",
    "longitude":"Lng"
})
renamed_csv_file.head()
# Out:
#    Job Posting ID                                          Job Title  \
# 0      1328241337  Physician: Florida Private Practice Looking fo...
# 1      1328242001  Physician: Urgent Care Physician Position in S...
# 2      1312805447  Physician: Obstetrics/Gynecology Opportunity i...
# 3      1316877274  Physician: Facility in PA Is Looking for a Tem...
# 4      1312804813  Physician: OB/GYN Needed in Carlsbad, New Mexi...
#
#                     Category Company Name                    Location  \
# 0  Healthcare & Nursing Jobs   CompHealth  Tampa, Hillsborough County
# 1  Healthcare & Nursing Jobs   CompHealth    Somerdale, Camden County
# 2  Healthcare & Nursing Jobs   CompHealth         Hobart, Lake County
# 3  Healthcare & Nursing Jobs   CompHealth            Pennsylvania, US
# 4  Healthcare & Nursing Jobs   CompHealth       Carlsbad, Eddy County
#
#          Lat         Lng
# 0  27.955269  -82.456320
# 1  39.844003  -75.022669
# 2  41.532259  -87.255035
# 3  40.819260  -77.565308
# 4  32.420674 -104.228838

# %%
#save raw data to dataRaw folder
renamed_csv_file.to_csv(orgRawData)

# %%
#calling the csv org data
org_csv_file = pd.read_csv(orgRawData)
org_csv_file.head()
# Out:
#    Unnamed: 0  Job Posting ID  \
# 0           0      1328241337
# 1           1      1328242001
# 2           2      1312805447
# 3           3      1316877274
# 4           4      1312804813
#
#                                            Job Title  \
# 0  Physician: Florida Private Practice Looking fo...
# 1  Physician: Urgent Care Physician Position in S...
# 2  Physician: Obstetrics/Gynecology Opportunity i...
# 3  Physician: Facility in PA Is Looking for a Tem...
# 4  Physician: OB/GYN Needed in Carlsbad, New Mexi...
#
#                     Category Company Name                    Location  \
# 0  Healthcare & Nursing Jobs   CompHealth  Tampa, Hillsborough County
# 1  Healthcare & Nursing Jobs   CompHealth    Somerdale, Camden County
# 2  Healthcare & Nursing Jobs   CompHealth         Hobart, Lake County
# 3  Healthcare & Nursing Jobs   CompHealth            Pennsylvania, US
# 4  Healthcare & Nursing Jobs   CompHealth       Carlsbad, Eddy County
#
#          Lat         Lng
# 0  27.955269  -82.456320
# 1  39.844003  -75.022669
# 2  41.532259  -87.255035
# 3  40.819260  -77.565308
# 4  32.420674 -104.228838

# %%
#Count Rows of all columns
org_csv_file.count()
# Out:
# Unnamed: 0        1000
# Job Posting ID    1000
# Job Title         1000
# Category          1000
# Company Name      1000
# Location          1000
# Lat                980
# Lng                980
# dtype: int64

# %%
#Remove unwanted column
del org_csv_file['Unnamed: 0']
org_csv_file.head()
# Out:
#    Job Posting ID                                          Job Title  \
# 0      1328241337  Physician: Florida Private Practice Looking fo...
# 1      1328242001  Physician: Urgent Care Physician Position in S...
# 2      1312805447  Physician: Obstetrics/Gynecology Opportunity i...
# 3      1316877274  Physician: Facility in PA Is Looking for a Tem...
# 4      1312804813  Physician: OB/GYN Needed in Carlsbad, New Mexi...
#
#                     Category Company Name                    Location  \
# 0  Healthcare & Nursing Jobs   CompHealth  Tampa, Hillsborough County
# 1  Healthcare & Nursing Jobs   CompHealth    Somerdale, Camden County
# 2  Healthcare & Nursing Jobs   CompHealth         Hobart, Lake County
# 3  Healthcare & Nursing Jobs   CompHealth            Pennsylvania, US
# 4  Healthcare & Nursing Jobs   CompHealth       Carlsbad, Eddy County
#
#          Lat         Lng
# 0  27.955269  -82.456320
# 1  39.844003  -75.022669
# 2  41.532259  -87.255035
# 3  40.819260  -77.565308
# 4  32.420674 -104.228838

# %%
#Delete Rows with missing data from lat and lng
clean_data = org_csv_file.dropna()
clean_data.count()
# Out:
# Job Posting ID    980
# Job Title         980
# Category          980
# Company Name      980
# Location          980
# Lat               980
# Lng               980
# dtype: int64

# %%
#Save clean data into cleanData folder
clean_data.to_csv(cleanData)

# %%
#Deleting rows with any missing data
#calling the csv org data
clean_csv_file = pd.read_csv(cleanData)

#Not sure why this column came back
del clean_csv_file['Unnamed: 0']

clean_csv_file.head()
# Out:
#    Job Posting ID                                          Job Title  \
# 0      1328241337  Physician: Florida Private Practice Looking fo...
# 1      1328242001  Physician: Urgent Care Physician Position in S...
# 2      1312805447  Physician: Obstetrics/Gynecology Opportunity i...
# 3      1316877274  Physician: Facility in PA Is Looking for a Tem...
# 4      1312804813  Physician: OB/GYN Needed in Carlsbad, New Mexi...
#
#                     Category Company Name                    Location  \
# 0  Healthcare & Nursing Jobs   CompHealth  Tampa, Hillsborough County
# 1  Healthcare & Nursing Jobs   CompHealth    Somerdale, Camden County
# 2  Healthcare & Nursing Jobs   CompHealth         Hobart, Lake County
# 3  Healthcare & Nursing Jobs   CompHealth            Pennsylvania, US
# 4  Healthcare & Nursing Jobs   CompHealth       Carlsbad, Eddy County
#
#          Lat         Lng
# 0  27.955269  -82.456320
# 1  39.844003  -75.022669
# 2  41.532259  -87.255035
# 3  40.819260  -77.565308
# 4  32.420674 -104.228838

# %%
#Calling Gmaps key
gmaps.configure(api_key= gkey) # Fill in with your API key
clean_csv_file_copy = clean_csv_file.copy()

#defining rows
lat = clean_csv_file_copy['Lat']
lng = clean_csv_file_copy['Lng']
cat = clean_csv_file_copy['Job Posting ID']

#Turning int to float for testing
cat = cat.astype('float')

# %%
#Gmaps testing
locations = clean_csv_file_copy[['Lat', 'Lng']]
fig = gmaps.figure(map_type='TERRAIN')



locations_layer = gmaps.symbol_layer(
    locations, fill_color='red', stroke_color='green', scale=1
)
fig = gmaps.figure()
fig.add_layer(locations_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Geting unique values
charr = clean_csv_file_copy['Category'].unique()
charr
# Out:
# array(['Healthcare & Nursing Jobs', 'Customer Services Jobs',
#        'Other/General Jobs', 'Unknown', 'Logistics & Warehouse Jobs',
#        'Sales Jobs'], dtype=object)

# %%
#categorizing category to display on map layter
index_cat = clean_csv_file_copy.set_index(['Category'])
cat = index_cat.loc["Sales Jobs"] 
healthcare = cat[['Lat', 'Lng']]
healthcare

# for c in range(len(charr)):
#     flag = index_cat.loc[c]
#     arm = flag[['Lat','Lng']]
    
clean_csv_file_copy
