# %%
#imports 
import json
import requests
import pandas as pd
import matplotlib as plt
import pprint as pprint

# %%
# Raw geo data file to be saved and pulled from
rawGeoData = "../data/rawData/zl_geo_raw_dataframe.csv"

# cleaned data file to be saved
cleanData = "../data/cleanData/zl_clean_data.csv"

# path csv file location
pathRawData = "../data/rawData/"
pathCleanData ="../datacleanData/"

# %%
#calling the csv raw data
geo_csv_file = pd.read_csv(rawGeoData)
geo_csv_file.head()
# Out:
#    Job Posting ID                                          Job Title  \
# 0      1312805093  Physician: Family Physician Job Opening in Ups...
# 1      1312805901  Physician: Urology Need in Western Ohio with L...
# 2      1328241931  Physician: Internal Medicine Physician Job in ...
# 3      1334502463  Physician: A Locums Otolaryngologist Is Wanted...
# 4      1312805719  Physician: Hospitalist needed in Hartford, CT ...
#
#                     Category Company Name                    Location  \
# 0  Healthcare & Nursing Jobs   CompHealth   Clayton, Jefferson County
# 1  Healthcare & Nursing Jobs   CompHealth                    Ohio, US
# 2  Healthcare & Nursing Jobs   CompHealth  Cheshire, New Haven County
# 3  Healthcare & Nursing Jobs   CompHealth   Marion, Williamson County
# 4  Healthcare & Nursing Jobs   CompHealth             Connecticut, US
#
#          Lat        Lng                                 LatLng  \
# 0  44.239491 -76.085776          44.239490999999994,-76.085776
# 1  40.305232 -82.824785  40.305232000000004,-82.82478499999998
# 2  41.508367 -72.910620                    41.508367,-72.91062
# 3  37.730605 -88.933126                   37.730605,-88.933126
# 4  41.601859 -72.657316   41.60185900000001,-72.65731600000002
#
#                                         geocode_data      city        state  \
# 0  {'address_components': [{'long_name': '512', '...   Clayton     New York
# 1  {'address_components': [{'long_name': '5629', ...   Sunbury         Ohio
# 2  {'address_components': [{'long_name': 'Cheshir...  Cheshire  Connecticut
# 3  {'address_components': [{'long_name': '805', '...    Marion     Illinois
# 4  {'address_components': [{'long_name': '87', 's...  Cromwell  Connecticut
#
#          country
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States

# %%
#Maiking a copy of Geo Data
geo_csv_file_copy = geo_csv_file.copy()
